# %% [markdown]
# ### Imports

# %%
import pandas as pd
from utils import *

# %% [markdown]
# ### Constants

# %%
data_path = "./data/data.csv"

# %% [markdown]
# ### Load Data

# %%
data = pd.read_csv(data_path)
print(data.head(5))
# Out:
#    acousticness                    artists  danceability  duration_ms  energy  \
# 0      0.991000            ['Mamie Smith']         0.598       168333   0.224
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852       150200   0.517
# 2      0.993000            ['Mamie Smith']         0.647       163827   0.186
# 3      0.000173        ['Oscar Velazquez']         0.730       422087   0.798
# 4      0.295000                   ['Mixe']         0.704       165224   0.707
#
#    explicit                      id  instrumentalness  key  liveness  \
# 0         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522    5    0.3790
# 1         0  0hbkKFIJm7Z05H8Zl9w30f          0.026400    5    0.0809
# 2         0  11m7laMUgmOKqI3oYzuhne          0.000018    0    0.5190
# 3         0  19Lc5SfJJ5O1oaxY0fpwfh          0.801000    2    0.1280
# 4         1  2hJjbsLCytGsnAHfdsLejp          0.000246   10    0.4020
#
#    loudness  mode                                               name  \
# ...

# %%
print(data.dtypes)
# Out:
# acousticness        float64
# artists              object
# danceability        float64
# duration_ms           int64
# energy              float64
# explicit              int64
# id                   object
# instrumentalness    float64
# key                   int64
# liveness            float64
# loudness            float64
# mode                  int64
# name                 object
# popularity            int64
# release_date         object
# speechiness         float64
# tempo               float64
# valence             float64
# year                  int64
# dtype: object

# %%
data.isnull().sum()
# Out:
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# valence             0
# year                0
# dtype: int64

# %%
mask = data.artists.apply(lambda x: "The Strokes" in x)
data[mask]
# Out:
#         acousticness                            artists  danceability  \
# 16126       0.022300                    ['The Strokes']         0.624
# 16130       0.004250                    ['The Strokes']         0.538
# 16506       0.000563                    ['The Strokes']         0.486
# 35548       0.000456                    ['The Strokes']         0.408
# 35628       0.147000                    ['The Strokes']         0.667
# 36444       0.023800                    ['The Strokes']         0.630
# 38010       0.983000                    ['The Strokes']         0.544
# 54496       0.011600                    ['The Strokes']         0.528
# 54504       0.003260                    ['The Strokes']         0.426
# 54858       0.312000                    ['The Strokes']         0.452
# 54906       0.000097                    ['The Strokes']         0.547
# 54970       0.003360                    ['The Strokes']         0.680
# ...

# %%
data[data.name.apply(lambda x: "cover" in x)]
# Out:
#         acousticness                                            artists  \
# 121         0.073900                                ['OsamaBeenLeanin']
# 11190       0.082300                                           ['Rush']
# 18006       0.000250                           ['Two Door Cinema Club']
# 49534       0.083400                                           ['Rush']
# 51014       0.027200                             ['The Rolling Stones']
# 57946       0.067700                     ['Lil Baby', 'Gunna', 'Drake']
# 78138       0.793000                           ['Alcoholics Anonymous']
# 90590       0.007830  ['Blaise Kolodychuk and the Fukachuk Egg Machi...
# 95630       0.907000  ['George Frideric Handel', 'The Liverpool Phil...
# 96978       0.983000  ['Gaetano Donizetti', 'Giuseppe Di Stefano', '...
# 100410      0.906000                                     ['Elton John']
# 103043      0.967000  ['George Frideric Handel', 'Robert Hale', 'The...
# ...
